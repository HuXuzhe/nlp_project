# %% [markdown]
# # 数据预处理部分

# %% [markdown]
# ## 读取数据

# %%
# %config ZMQInteractiveShell.ast_node_interactivity = 'all'
import warnings
warnings.filterwarnings('ignore')
# %pprint
# Out:
# Pretty printing has been turned ON

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("./data/train.csv", sep="###__###", names=['ID', 'Age', 'Gender', 'Education', 'Query_List'],
                    encoding='utf-8', index_col=False)
test = pd.read_csv("./data/test.csv", sep="###__###",names=['ID', 'Query_list'], encoding='utf-8',
                   index_col=False)

# %% [markdown]
# 添加“header=None”，告诉函数，我们读取的原始文件数据没有列索引。因此，read_csv为自动加上列索引

# %%
# train.columns = ['ID', 'Age', 'Gender', 'Education', 'Query_List']
train.head()
train.shape
# Out:
#                                  ID  Age  Gender  Education  \
# 0  22DD920316420BE2DF8D6EE651BA174B    1       1          4
# 1  43CC3AF5A8D6430A3B572337A889AFE4    2       1          3
# 2  E97654BFF5570E2CCD433EA6128EAC19    4       1          0
# 3  6931EFC26D229CCFCEA125D3F3C21E57    4       2          3
# 4  E780470C3BB0D340334BD08CDCC3C71A    2       2          4
#
#                                           Query_List
# 0  柔和双沟\t女生\t中财网首页 财经\thttp://pan.baidu.com/s/1pl...
# 1  广州厨宝烤箱\t世情薄,人情恶,雨送黄昏花易落,晓风干,泪痕\t厦门酒店用品批发市场\t我只...
# 2  钻石之泪耳机\t盘锦到沈阳\t旅顺公交\t辽宁阜新车牌\tbaidu\tk715\tk716...
# 3  最受欢迎狗狗排行榜\t舶怎么读\t场景描 写范例\t三维绘图软件\t枣和酸奶能一起吃吗\t好...
# 4  干槽症能自愈吗\t太太万岁叶舒心去没去美国\t干槽症\t右眼皮下面一直跳是怎么回事\t麦当劳...
# (100000, 5)

# %%
train.ID
# Out:
# 0        22DD920316420BE2DF8D6EE651BA174B
# 1        43CC3AF5A8D6430A3B572337A889AFE4
# 2        E97654BFF5570E2CCD433EA6128EAC19
# 3        6931EFC26D229CCFCEA125D3F3C21E57
# 4        E780470C3BB0D340334BD08CDCC3C71A
# 5        5BB424C7298B2CB67C368DDB73D4D336
# 6        0D58894CD481D4B3039000661665C0DB
# 7        0BA56489237BC91353300BE44298C6D8
# 8        3D39C1B9312105E030B039CCDCD79611
# 9        93174489E2E708BF6F797DC69F1531A8
# 10       410891627A7284154408E9AB188DC6F4
# 11       AE2FCEA2720A3E8A9B81C11AE8FF13D6
# 12       3CEC23FD112E92FD34339A1D18208F9B
# 13       76115B7052E2D3C40C731F6ACB40907D
# 14       35A1C01D912F88909320947C35E231A6
# 15       70901A790856356C1193040D4952233A
# 16       C4834FD969574A71FD08D10CF73AD60B
# 17       A3A0E25C1D63AAC3041EFEDC95CF8A9C
# 18       FE0FE26A221ABC61997986CAC2BB82FF
# 19       72759C67B21282FDCB01CEAE67864CFB
# 20       B62AB59182F2C975FE0A7CDDAB8294AE
# 21       8B9A1E907764F67D170A1F5984B96F6E
# 22       20858CECBD8ED448A64B70C756ED8DEA
# 23       A9EB0BED8D34ABB58AF6B24204EE05F8
# 24       266B8A299027974CC66FB5E0B398B8B2
# 25       FFF9CBCF1EA518CBD69266258684E0E4
# 26       69EC910FB16C765AC443C99234A5FB32
# 27       B6C0F8CD6AB13E282F25A3F7CDC32742
# 28       953FED4A0C0DB6214D78FB953A2BD245
# 29       8D0D77F0A9792AE50DDD7B2F70DCCECF
#                        ...
# 99970    2A266676C2AE311E47A3F3A59E111EBD
# 99971    86F0CC4E803E4ED4077898CD5450E285
# 99972    6E6F0945D39C5CC1A5A7D5758A2C954E
# 99973    17082CE5F95A96FFD58D8150ADF03650
# 99974    494F9F8E5CC6D124D7DB15C960ABEAF5
# 99975    4E2655F9F7FF220ED62D2A79530D7AC7
# 99976    134305D888D1DEB6015A359DC522D712
# 99977    EB3824FE3721B66F4E9208024BC53364
# 99978    6BB246C306E4ADCDF1AEFBC0450FBFA9
# 99979    D777C6A7B979DCDFE2B75267CD733918
# 99980    90EB3563191F2CAA64C9E95B8E022EF6
# 99981    F2B2E6275EDDD70BA9205DEAA7114440
# 99982    40D8233E5EB71A39982B1E7329F6DD0D
# 99983    13712DEADB207055D1D19B54E6CE559D
# 99984    60374EE8CA7A781556008EE46046C182
# 99985    94EC9E7AFCD7A00D632C1E38A380190A
# 99986    F7F7782B6220D561A69B173364CC6D73
# 99987    362E66D7D852A70589187D6337A089D7
# 99988    4800297F41065EEF2C629D0312B339CB
# 99989    23135A9F0D5278B8C8DA2519CE22C91A
# 99990    5C864287F44975097E53F97B593385F8
# 99991    FD2BB80457ED4E2222D6D65B5C0A6081
# 99992    4A105229304B89B46CB2CCB89949F9CD
# 99993    25741C9F979E43B617F3F13ADA2AC94A
# 99994    A1A6E73E9A0AF7D63EB04B683EEC6069
# 99995    E797FFCDCAF3899AB4D17B61170D8BFF
# 99996    E06375F7D092ABDE78C2D79E4725D6B0
# 99997    D55119CB0B9366B20974522B58C00912
# 99998    EB4DBBD602C6459A19A77F09035E170C
# 99999    61CF81DB79423CB89E5DAA752BC4D9DD
# Name: ID, Length: 100000, dtype: object

# %%
# test.columns = ['ID', 'Query_List']
test.head()
test.shape
# Out:
#                                  ID  \
# 0  ED89D43B9F602F96D96C25255F7C228C
# 1  83C3B7B4AAF8074655A8079F561A76D6
# 2  CA9F675A024FB2353849350A35CF8B0F
# 3  DE45B5C4E57AAEBCF3FDFA2A774093BF
# 4  406A681FB3DF81EC0E561796AE50AE50
#
#                                           Query_list
# 0  陈学冬将出的作品\t刘昊然与谭松韵\t211学校的分数线\t谁唱的味道好听\t吻戏是真吻还是...
# 1  e的0.0052次方\tqq怎么快速提现\t绝色倾城飞烟\t马克思主义基本原理概论\t康世恩...
# 2  黑暗文\tlpl夏季赛\t大富豪电玩城\t英雄联盟之电竞称王\t手机怎么扫描手机上的二维码\...
# 3  中秋水库钓鱼\t鱼竿\t用蚯蚓钓鱼怎样调漂\t传统钓\t3号鱼钩\t鲫鱼汤的做法大全\t鱼饵...
# 4  号码吉凶\t退休干部死后配偶\t郫县有哪些大学\t胜利油田属于中石化还是中石油\t苏珊米勒狮...
# (100000, 2)

# %% [markdown]
# ## 查看数据是否有缺失值，是否需要dropna

# %%
train.isnull().sum()
test.isnull().sum()
# Out:
# ID            0
# Age           0
# Gender        0
# Education     0
# Query_List    0
# dtype: int64
# ID            0
# Query_list    0
# dtype: int64

# %% [markdown]
# ## 处理query_list中的的词语

# %%
train.Query_List
# Out:
# 0        柔和双沟\t女生\t中财网首页 财经\thttp://pan.baidu.com/s/1pl...
# 1        广州厨宝烤箱\t世情薄,人情恶,雨送黄昏花易落,晓风干,泪痕\t厦门酒店用品批发市场\t我只...
# 2        钻石之泪耳机\t盘锦到沈阳\t旅顺公交\t辽宁阜新车牌\tbaidu\tk715\tk716...
# 3        最受欢迎狗狗排行榜\t舶怎么读\t场景描 写范例\t三维绘图软件\t枣和酸奶能一起吃吗\t好...
# 4        干槽症能自愈吗\t太太万岁叶舒心去没去美国\t干槽症\t右眼皮下面一直跳是怎么回事\t麦当劳...
# 5        钢琴曲欣赏100首\t一个月的宝宝眼睫毛那么是黄色\t宝宝右眼有眼屎\t小儿抽搐怎么办\t剖...
# 6        貔貅饲育指南\t韩姨\t贵阳学古琴\t洛基\t风速狗\t综英美]店主不好吃\t>重生之被拐儿...
# 7        昂的笔顺\t三年级上册数学口算\t牛的英语怎么读\t抓木机\t60米差不多跑多长时间\t似乎...
# 8        李明霖在哪直播\t英文翻译\t薄荷籽\t为什么搜狐视频不能缓存\t有一首歌女生唱的歌词是冬天...
# 9        bft20\t龙王传说\t长治到成都可以怎么坐火车\t龙王传说txt\t2 4 8 16老司...
# 10       宠辱小说\t陶喆的歌\t类似宝宝穿越记恋童文\t禁爱诱惑\t库克抛售苹果股份\t老人要1元赡...
# 11       lephone是什么牌子的手机\t乳母动漫全集在线观看\t女鬼图片唯美\t使命召唤ol\t魔...
# 12       电信宽带送手机\t李敏镐做饭\thpv是什么\t无锡人民医院皮肤科\t乘法运算定律\t历年金...
# 13       功夫圣医叶诚\tvivox7处理器位数\t近身保镖\t大主宰\t上龙\t网王幻之子\t绝色老...
# 14       多亮你的背包\t2015合肥10路公交车路线查询\t量子卫星\t皖南医学院的三本专业\t近期...
# 15       吴靖平\t使用假征值税发票属什么行为\t抽到81签的解释\t奔驰车轿车为什么不是大标志图\t...
# 16       笔记本电脑500g硬盘\twindows7ultimate\t音频驱动器官方下载\t助学贷款...
# 17       脓包怎么快速去除\t高考体检\t生完孩子之后腰疼是怎么回事\t上学期用英语怎么说\t苹果手机...
# 18       奶油柠檬漫画\t精灵梦叶罗丽第五季\t广播\t师大的被褥贵么\t联想700s怎么关不机\t密...
# 19       公共自助洗衣机的用法\t跟圣女果差不多大小的辣椒是什么品种的\t高潮\t极品教师\t我和老板...
# 20       普通脉冲雷达怎么抑制地面回波\t郭富城电影\tvc怎么解码h.264\t抓鸟判刑,民众保护意...
# 21       奈落\t英语\t威武霸气帅下一句什么1002威武霸气帅下一句\t知道有他在你心里的位置\t威...
baidu.com/s/1nu9uizn 钢弩 冰川世纪电影 全文 触手蓝烟 鱼的做法 金罐加多宝20罐 澳洲托运行李规定 15346171303@189.cn 炒蒜苔的家常做法 被时光掩埋的秘密 根号13.6等于几 方特东方神画 粉红花朵图片 qq号申请 千亿盛宠 大叔吻慢点 http://linjiada1989.1688.com 东方财富网首页 http://pan.baidu.com/s/1hraemhe 动力煤价格 手机遥控魔棒 jzg http://pan.baidu.com/s/1o8cxpmm 行李托运到澳洲 蚬壳胃散副作用 红烧鲤鱼 触手tv 中国财经信息网中财网 立方根800 美食菜谱 笑傲江湖电视剧 柔和双沟怎么样 笑傲江湖 花的品种名字及图片 滴滴司机端 奇怪君 鸡蛋灌饼 天龙农家乐园 吉拉拉歌词 陈翔的女朋友 牢解场的生活 微微一笑很倾城 豪门少奶奶谢少的心尖宠妻'

# %%
tmp2 = train.Query_List[0].replace('\t', ' ').split()
len(tmp2)
# Out:
# 283

# %%
# 全角符号的英文

list(filter(lambda x: x[:4]=='http' or x[-3:]=='ｃｏｍ' or x[-3:] == 'com' or x[-2:]=='cn', tmp2))
# Out:
# ['http://pan.baidu.com/s/1plpjtn9',
#  'https://yunpan.cn/ocsqfgtfya2ewj',
#  'http://zxjhjc9088.1688.com',
#  'http://pan.baidu.com/s/1cor7gy',
#  'http://pan.baidu.com/s/1jhbv9pg',
#  'http://pan.baidu.com/s/1o7hnpmy',
#  'ｗｗｗ．２０１６ｙｇ．ｃｏｍ',
#  'http://m37189.mustfollow.vx.mvote.net/wx',
#  'http://www.cswanda.com/weixin/game1/2016',
#  'https://yunpan.cn/oc6nhvmrg5j2ur',
#  'http://pan.baidu.com/s/1nu9uizn',
#  '15346171303@189.cn',
#  'http://linjiada1989.1688.com',
#  'http://pan.baidu.com/s/1hraemhe',
#  'http://pan.baidu.com/s/1o8cxpmm']

# %%
tmp3 = [item for item in tmp2 if 'http' not in item and 'ｃｏｍ' not in item and 
        'com' not in item and 'cn' not in item]

tmp3
# Out:
# ['柔和双沟',
#  '女生',
#  '中财网首页',
#  '财经',
#  '周公解梦大全查询2345',
#  '曹云金再讽郭德纲',
#  '总裁大人行行好',
#  '中财网第一财经传媒',
#  '教师节全文',
#  '男子砸毁15墓碑',
#  '黄岩岛最新填海图',
#  '引起的疲',
#  '缘来未迟落跑甜心不好惹',
#  '梁朝伟与替身同框',
#  '笑傲江湖电视剧任贤齐',
#  '小起名字女孩名字',
#  '海运行李到堪培拉',
#  '确定',
#  '诱爱99天',
#  '司少的天价宝贝',
#  '什么是遥控魔棒',
#  '徽信表情动态搞笑图片',
#  '教师节征文100字',
#  '安微联通网上营业厅',
#  '甜宠百分百:校草的萌萌未婚妻',
#  '豪门重生之暖爱成婚',
#  'nikehypershift和kd5哪个好看',
#  '韭菜炒鸡蛋',
#  '陈赫玩王者荣耀',
#  '虎牙楚河',
#  '三国演义小说txt下载',
#  '威县欧派',
#  '炒馍花怎么做好吃',
#  '黄岩岛最新消息2016年',
#  '中秋节诗句大全祝福',
#  '教师节征文',
#  '菜谱',
#  '柔和双沟卖的怎么样',
#  '七位数开奖结果',
#  '以色列停车场坍塌',
#  '天龙家庭农场',
#  '7.22什么星座',
#  '新旧约圣经和合本下载',
#  '4π',
#  'wifi万能钥匙',
#  '威灵仙图片',
#  '临泉长官天龙家庭农场',
#  '早安总统大人',
#  '百合',
#  '莲藕的做法',
#  '花街',
#  '无锡',
#  '蚬壳胃散怎么吃',
#  '触手忆寒',
#  '中秋节的诗句',
#  '孟州电信',
#  '电子发票',
#  '鸡丝汤的做法',
#  '我等你',
#  '临泉长官镇桥口李小刚农场',
#  '朋仇',
#  '全民k歌',
#  '炸葱花',
#  '蒜苔炒肉',
#  '冰川的图片',
#  'kd5',
#  '…',
#  '若风',
#  '好奇纸尿裤',
#  '清蒸鱼',
#  '189.8是谁的平方',
#  '重庆餐馆发生爆炸',
#  '捡手机被失主抢劫',
#  '炒馍花的家常做法',
#  '三国演义小说百度云',
#  '总裁掠爱小舅别太坏',
#  '周公解梦',
#  '查坦克冰川',
#  '凉拌藕片的做法',
#  '投票',
#  '鸡丝炒什么好吃',
#  '被时光掩埋的秘密小说下载',
#  '中国电信电子发票',
#  '张续豪',
#  '关于月亮的诗句',
#  '用酵母蒸馒头的方法',
#  '赵丽颖碧瑶坐',
#  '触手兵长',
#  '图集',
#  '下载腾讯新闻,看街头混战武警',
#  '厦门航空',
#  '蚬壳胃散',
#  '炒茄子做法',
#  '身份类别怎么填',
#  '最好的我们里面的方特在哪里',
#  '牢里面的生活是怎样的',
#  '强迫症有哪些表现',
#  '白袍法师暖暖图片',
#  '朋仇广场舞',
#  '小宇热游',
#  '蒸馒头的方法',
#  '狡滑的意思',
#  '黄石大冶东岳派出所服务电话',
#  '三国演义小说下载txt',
#  '松柏道馆',
#  '10.1高速免费几天',
#  '三国演义小说txt',
#  '柔和双沟业务待遇',
#  '酵母蒸馒头的方法',
#  '初中家教一对一辅导',
#  '口子窖',
#  '中秋节祝福诗句',
#  '侠岚',
#  '文王国窖42度价格表1001文王国窖42度价格表',
#  '批注是什么意思',
#  '殿下专属小丫头',
#  '无锡爆炸',
#  '炸茄子做法',
#  '大件行李邮寄',
#  '烟火陈翔',
#  '没想到,真没想到作文',
#  '安徽滁州石坝镇',
#  '虎牙小宇',
#  '驾校培训跑长途',
#  '骨质性关节炎',
#  '左膝盖内侧疼是怎么回事',
#  '虎皮尖椒的做法大全',
#  '陈翔的女朋友吻照',
#  'q我的世界、5',
#  '23.04的平方根',
#  '神将世界表情包',
#  '寻找成龙',
#  '柔和双沟卖的',
#  '三国演义txt百度云',
#  '一般现在时',
#  '澳洲邮寄行李费用',
#  '触手若月',
#  '1991年11月26日是什么星座',
#  '校草成长记',
#  '暮光女向女友求婚',
#  '钢弩的价格图片',
#  '乐乐课堂',
#  '宠妻成瘾老婆你要乖',
#  '魔手tv',
#  '梅河口到济南的火车票',
#  '临泉长官镇',
#  '君子兰',
#  '南洋十大邪术电影',
#  '肚',
#  '炸油条的做法和配方',
#  '根号6等于多少',
#  '笑笑昨日帝王骗',
#  '吃惊的什么填词语',
#  '50字教师节征文',
#  '朝阳区黑庄户邮编',
#  '千百鲁',
#  '1991年农历11月26日是什么星座',
#  '圣经和合本免费下载',
#  '水煮花生米的做法',
#  '十字弓',
#  '徽信表情含义',
#  '天才小熊猫微博长图',
#  '宠冠六宫:帝王的娇蛮皇妃',
#  '去广告软件',
#  '安卓版',
#  '萌妻娇俏帝少我嘴挑',
#  '总裁霸爱小小新娘要逃婚',
#  '花生怎么煮好吃',
#  '中国证券网',
#  '柔和双沟销售',
#  '中秋节的诗句图片',
#  '男子怪病喝洗洁精',
#  '4π等于多少',
#  '服装批发5元',
#  '怀孕33周肚子隐隐作痛怎么回事',
#  '百度云',
#  '酱炒蒜苔的家常做法',
#  '水煮花生米',
#  '天才小熊猫作品',
#  '袁姗姗',
#  '临泉长官镇桥口',
#  '呼作白玉盘的上一句',
#  '微信表情包搞笑图片',
#  '滴滴快车司机端',
#  '教师节手抄报简单好看',
#  '大冶公安局',
#  '派出所',
#  '柔和双沟业务待遇怎么样',
#  '为什么哺乳期不会有月经',
#  '临泉长官水上乐园',
#  '忐忑不安的意思',
#  '临泉长官李小刚家庭农场',
#  '电信电子发票怎么报销',
#  '岳不群',
#  '临泉长官镇桥口李天龙农场',
#  '凉拌水煮花生米的做法',
#  '威灵仙的功效与作用',
#  '鸽子汤的做法',
#  '战神伪高冷',
#  '天降医妃拐回家',
#  '白颠疯初期症状',
#  '天才小熊猫',
#  '首席萌妻咬一口',
#  '弩弓枪商城',
#  '三国演义小说',
#  '临泉长官镇桥口植物养殖基地',
#  '邮储银行手机银行客户端下载',
#  '煮花米怎么做好吃',
#  '英语在线翻译',
#  '糖醋鲤鱼',
#  '搞笑微信表情图片带字',
#  '新婚甜似火:鲜妻,二胎生一对',
#  '三国演义',
#  '关于教师节的手抄报',
#  '文王国窖42度价格表',
#  '鱼汤的做法',
#  '临泉长官镇桥口私人农场',
#  '临泉长官镇桥口镇杨营',
#  '临泉长官李天龙家庭农场',
#  '李子树根部有脓包怎么回事',
#  '单手高速转牌',
#  '医学院在什么路上',
#  '徽信早上好动态表情',
#  '宝宝小名大全2016洋气',
#  '寂寞男女聊天记录截图',
#  '神将世界',
#  '美丽的秋天作文300字',
#  '钢弩',
#  '冰川世纪电影',
#  '全文',
#  '触手蓝烟',
#  '鱼的做法',
#  '金罐加多宝20罐',
#  '澳洲托运行李规定',
#  '炒蒜苔的家常做法',
#  '被时光掩埋的秘密',
#  '根号13.6等于几',
#  '方特东方神画',
#  '粉红花朵图片',
#  'qq号申请',
#  '千亿盛宠',
#  '大叔吻慢点',
#  '东方财富网首页',
#  '动力煤价格',
#  '手机遥控魔棒',
#  'jzg',
#  '行李托运到澳洲',
#  '蚬壳胃散副作用',
#  '红烧鲤鱼',
#  '触手tv',
#  '中国财经信息网中财网',
# 2           all
# 3            例如
# 4          ［④ｅ］
# 5          when
# 6             亦
# 7            来讲
# 8            谁料
# 9            届时
# 10         或多或少
# 11           不外
# 12           即使
# 13           独自
# 14            啐
# 15           反倒
# 16           ＝☆
# 17       you'll
# 18           ＋ξ
# 19           哎呀
# 20          yet
# 21           从轻
# 22          切不可
# 23           举行
# 24    specified
# 25           进而
# 26            ]
# 27         ［②ｇ］
# 28        hello
# 29            嗡
# ...         ...
# 2430         下去
# 2431         当即
# 2432         自己
# 2433          乒
# 2434          也
# 2435         你的
# 2436         比较
# 2437         必然
# 2438        大体上
# 2439         几乎
# 2440          ︿
# 2441         有效
# 2442         他的
# 2443        到了儿
# 2444         ②ｃ
# 2445         就此
# 2446         所幸
# 2447         转贴
# 2448          】
# 2449       ［③⑩］
# 2450       soon
# 2451         比如
# 2452         快要
# 2453       done
# 2454        什么样
# 2455      maybe
# 2456      which
# 2457          欤
# 2458         最近
# 2459         当前
#
# [2460 rows x 1 columns]

# %%
stopwords_list = stopwords.stopwords.values
stopwords_list
# Out:
# array(['为止', '纵然', 'all', ..., '欤', '最近', '当前'], dtype=object)

# %%
# 此处可以优化的地方就是加一些自定义的词典

import jieba
segs = jieba.lcut(tmp4, cut_all=False, HMM=True)
segs = list(filter(lambda x: len(x)>1 and x!='\r\n', segs))
segs = list(filter(lambda x: x not in stopwords_list, segs))
segs
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/dm/36t_vnm94bn9mc2bts9v0qw40000gn/T/jieba.cache
# Loading model cost 0.678 seconds.
# Prefix dict has been built successfully.
# ['柔和',
#  '双沟',
#  '女生',
#  '中财网',
#  '首页',
#  '财经',
#  '周公',
#  '解梦',
#  '大全',
#  '查询',
#  '2345',
#  '曹云金',
#  '再讽',
#  '郭德纲',
#  '总裁',
#  '大人',
#  '行行好',
#  '中财网',
#  '第一',
#  '财经',
#  '传媒',
#  '教师节',
#  '全文',
#  '男子',
#  '砸毁',
#  '15',
#  '墓碑',
#  '黄岩岛',
#  '最新',
#  '海图',
#  '缘来',
#  '迟落',
#  '甜心',
#  '不好惹',
#  '梁朝伟',
#  '替身',
#  '同框',
#  '笑傲江湖',
#  '电视剧',
#  '任贤齐',
#  '小起',
#  '名字',
#  '女孩',
#  '名字',
#  '海运',
#  '行李',
#  '堪培拉',
#  '诱爱',
#  '99',
#  '司少',
#  '天价',
#  '宝贝',
#  '遥控',
#  '魔棒',
#  '徽信',
#  '表情',
#  '动态',
#  '搞笑',
#  '图片',
#  '教师节',
#  '征文',
#  '100',
#  '安微',
#  '联通',
#  '网上',
#  '营业厅',
#  '甜宠',
#  '百分百',
#  '校草',
#  '萌萌',
#  '未婚妻',
#  '豪门',
#  '重生',
#  '之暖爱',
#  '成婚',
#  'nikehypershift',
#  'kd5',
#  '好看',
#  '韭菜',
#  '炒鸡蛋',
#  '陈赫',
#  '王者',
#  '荣耀',
#  '虎牙',
#  '楚河',
#  '三国演义',
#  '小说',
#  'txt',
#  '下载',
#  '威县',
#  '欧派',
#  '好吃',
#  '黄岩岛',
#  '最新消息',
#  '2016',
#  '中秋节',
#  '诗句',
#  '大全',
#  '祝福',
#  '教师节',
#  '征文',
#  '菜谱',
#  '柔和',
#  '双沟',
#  '七位数',
#  '开奖',
#  '以色列',
#  '停车场',
#  '坍塌',
#  '天龙',
#  '家庭',
#  '农场',
#  '7.22',
#  '星座',
#  '新旧',
#  '圣经',
#  '合本',
#  '下载',
#  'wifi',
#  '万能钥匙',
#  '威灵仙',
#  '图片',
#  '临泉',
#  '长官',
#  '天龙',
#  '家庭',
#  '农场',
#  '早安',
#  '总统',
#  '大人',
#  '百合',
#  '莲藕',
#  '做法',
#  '花街',
#  '无锡',
#  '蚬壳',
#  '胃散',
#  '触手',
#  '忆寒',
#  '中秋节',
#  '诗句',
#  '孟州',
#  '电信',
#  '电子',
#  '发票',
#  '鸡丝',
#  '做法',
#  '临泉',
#  '长官',
#  '镇桥口',
#  '李小刚',
#  '农场',
#  '朋仇',
#  '全民',
#  '葱花',
#  '蒜苔',
#  '炒肉',
#  '冰川',
#  '图片',
#  'kd5',
#  '若风',
#  '好奇',
#  '纸尿裤',
#  '清蒸鱼',
#  '189.8',
#  '平方',
#  '重庆',
#  '餐馆',
#  '发生爆炸',
#  '手机',
#  '失主',
#  '抢劫',
#  '家常',
#  '做法',
#  '三国演义',
#  '小说',
#  '百度',
#  '总裁',
#  '掠爱',
#  '小舅',
#  '太坏',
#  '周公',
#  '解梦',
#  '坦克',
#  '冰川',
#  '凉拌',
#  '藕片',
#  '做法',
#  '投票',
#  '鸡丝',
#  '好吃',
#  '时光',
#  '掩埋',
#  '秘密',
#  '小说',
#  '下载',
#  '中国电信',
#  '电子',
#  '发票',
#  '张续',
#  '月亮',
#  '诗句',
#  '酵母',
#  '馒头',
#  '方法',
#  '赵丽颖',
#  '碧瑶',
#  '触手',
#  '兵长',
#  '图集',
#  '下载',
#  '腾讯',
#  '新闻',
#  '街头',
#  '混战',
#  '武警',
#  '厦门航空',
#  '蚬壳',
#  '胃散',
#  '茄子',
#  '做法',
#  '身份',
#  '类别',
#  '方特',
#  '生活',
#  '强迫症',
#  '表现',
#  '白袍',
#  '法师',
#  '图片',
#  '朋仇',
#  '广场',
#  '小宇',
#  '热游',
#  '馒头',
#  '方法',
#  '狡滑',
#  '黄石',
#  '大冶',
#  '东岳',
#  '派出所',
#  '服务',
#  '电话',
#  '三国演义',
#  '小说',
#  '下载',
#  'txt',
#  '松柏',
#  '道馆',
#  '10.1',
#  '高速',
#  '免费',
#  '几天',
#  '三国演义',
#  '小说',
#  'txt',
#  '柔和',
#  '双沟',
#  '业务',
#  '待遇',
#  '酵母',
#  '馒头',
#  '方法',
#  '初中',
#  '家教',
#  '一对一',
#  '辅导',
#  '口子',
#  '中秋节',
#  '祝福',
#  '诗句',
#  '侠岚',
#  '王国',
#  '42',
#  '价格表',
#  '1001',
#  '王国',
#  '42',
#  '价格表',
#  '批注',
#  '殿下',
#  '专属',
#  '小丫头',
#  '无锡',
#  '爆炸',
#  '茄子',
#  '做法',
#  '大件',
#  '行李',
#  '邮寄',
#  '烟火',
#  '陈翔',
#  '没想到',
#  '真没想到',
#  '作文',
#  '安徽',
#  '滁州',
#  '石坝',
#  '虎牙',
#  '小宇',
#  '驾校',
#  '培训',
#  '长途',
#  '骨质',
#  '关节炎',
#  '膝盖',
#  '内侧',
#  '怎么回事',
#  '虎皮',
#  '尖椒',
#  '做法',
#  '大全',
#  '陈翔',
#  '女朋友',
#  '吻照',
#  '世界',
#  '23.04',
#  '平方根',
#  '神将',
#  '世界',
#  '表情',
#  '寻找',
#  '成龙',
#  '柔和',
#  '双沟',
#  '三国演义',
#  'txt',
#  '百度',
#  '澳洲',
#  '邮寄',
#  '行李',
#  '费用',
#  '触手',
#  '1991',
#  '11',
#  '26',
#  '星座',
#  '校草',
#  '成长',
#  '暮光',
#  '女友',
#  '求婚',
#  '钢弩',
#  '价格',
#  '图片',
#  '乐乐',
#  '课堂',
#  '宠妻',
#  '成瘾',
#  '老婆',
#  '魔手',
#  'tv',
#  '梅河口',
#  '济南',
#  '火车票',
#  '临泉',
#  '长官',
#  '君子兰',
#  '南洋',
#  '十大',
#  '邪术',
#  '电影',
#  '炸油条',
#  '做法',
#  '配方',
#  '根号',
#  '等于',
#  '笑笑',
#  '昨日',
#  '帝王',
#  '吃惊',
#  '词语',
#  '50',
#  '教师节',
#  '征文',
#  '朝阳区',
#  '庄户',
#  '邮编',
#  '千百',
#  '1991',
#  '农历',
#  '11',
#  '26',
#  '星座',
#  '圣经',
#  '合本',
#  '免费',
#  '下载',
#  '水煮',
#  '花生米',
#  '做法',
#  '十字',
#  '徽信',
#  '表情',
#  '含义',
#  '天才',
#  '小熊猫',
#  '微博长',
#  '宠冠六宫',
#  '帝王',
#  '娇蛮',
#  '皇妃',
#  '广告',
#  '软件',
#  '安卓版',
#  '萌妻',
#  '娇俏帝',
#  '总裁',
#  '霸爱',
#  '小小',
#  '新娘',
#  '逃婚',
#  '花生',
#  '好吃',
#  '中国',
#  '证券网',
#  '柔和',
#  '双沟',
#  '销售',
#  '中秋节',
#  '诗句',
#  '图片',
#  '男子',
#  '怪病',
#  '洗洁精',
#  '等于',
#  '服装',
#  '批发',
#  '怀孕',
#  '33',
#  '肚子',
#  '隐隐作痛',
#  '怎么回事',
#  '百度',
#  '蒜苔',
#  '家常',
#  '做法',
#  '水煮',
#  '花生米',
#  '天才',
#  '小熊猫',
#  '作品',
#  '袁姗姗',
#  '临泉',
#  '长官',
#  '镇桥口',
#  '呼作',
#  '白玉',
#  '一句',
#  '微信',
#  '表情',
#  '搞笑',
#  '图片',
#  '滴滴',
#  '快车',
#  '司机',
#  '教师节',
#  '手抄报',
#  '简单',
#  '好看',
#  '大冶',
#  '公安局',
#  '派出所',
#  '柔和',
#  '双沟',
#  '业务',
#  '待遇',
#  '哺乳期',
#  '月经',
#  '临泉',
#  '长官',
#  '水上',
#  '乐园',
#  '忐忑不安',
#  '临泉',
#  '长官',
#  '李小刚',
#  '家庭',
#  '农场',
#  '电信',
#  '电子',
#  '发票',
#  '报销',
#  '岳不群',
#  '临泉',
#  '长官',
#  '镇桥口',
#  '天龙',
#  '农场',
#  '凉拌',
#  '水煮',
#  '花生米',
#  '做法',
#  '威灵仙',
#  '功效',
#  '作用',
#  '鸽子',
#  '做法',
#  '战神',
#  '伪高冷',
#  '天降',
#  '医妃',
#  '回家',
#  '白颠',
#  '初期',
#  '症状',
#  '天才',
#  '小熊猫',
#  '首席',
#  '萌妻',
#  '咬一口',
#  '弩弓',
#  '商城',
#  '三国演义',
#  '小说',
#  '临泉',
#  '长官',
#  '镇桥口',
#  '植物',
#  '养殖',
#  '基地',
#  '邮储',
#  '银行',
#  '手机',
#  '银行',
#  '客户端',
#  '下载',
#  '花米',
#  '好吃',
#  '英语',
#  '在线翻译',
#  '糖醋',
#  '鲤鱼',
#  '搞笑',
#  '微信',
#  '表情图片',
#  '带字',
#  '新婚',
#  '似火',
#  '鲜妻',
#  '胎生',
#  '一对',
#  '三国演义',
#  '教师节',
#  '手抄报',
#  '王国',
#  '42',
#  '价格表',
#  '鱼汤',
#  '做法',
#  '临泉',
#  '长官',
#  '镇桥口',
#  '私人',
#  '农场',
#  '临泉',
#  '长官',
#  '镇桥',
#  '口镇',
#  '杨营',
#  '临泉',
#  '长官',
#  '天龙',
#  '家庭',
#  '农场',
#  '李子树',
#  '根部',
#  '脓包',
#  '怎么回事',
#  '单手',
#  '高速',
#  '转牌',
#  '医学院',
#  '路上',
#  '徽信',
#  '早上好',
#  '动态',
#  '表情',
#  '宝宝',
#  '小名',
#  '大全',
#  '2016',
#  '洋气',
#  '寂寞',
#  '男女',
#  '聊天记录',
#  '截图',
#  '神将',
#  '世界',
#  '美丽',
#  '秋天',
#  '作文',
#  '300',
#  '钢弩',
#  '冰川',
#  '世纪',
#  '电影',
#  '全文',
#  '触手',
#  '蓝烟',
#  '做法',
#  '金罐',
#  '加多宝',
#  '20',
#  '澳洲',
#  '托运',
#  '行李',
#  '蒜苔',
#  '家常',
#  '做法',
#  '时光',
#  '掩埋',
#  '秘密',
#  '根号',
#  '13.6',
#  '等于',
#  '方特',
#  '东方',
#  '神画',
#  '粉红',
#  '花朵',
#  '图片',
#  'qq',
#  '申请',
#  '千亿',
#  '盛宠',
#  '大叔',
#  '慢点',
#  '东方',
#  '财富网',
#  '首页',
#  '动力',
#  '价格',
#  '手机',
#  '遥控',
#  '魔棒',
#  'jzg',
#  '行李',
#  '托运',
#  '澳洲',
#  '蚬壳',
#  '胃散',
#  '副作用',
#  '红烧',
#  '鲤鱼',
#  '触手',
#  'tv',
#  '中国',
#  '财经',
#  '信息网',
#  '中财网',
#  '立方根',
#  '800',
#  '美食',
#  '菜谱',
#  '笑傲江湖',
#  '电视剧',
#  '柔和',
#  '双沟',
#  '笑傲江湖',
#  '品种',
#  '名字',
#  '图片',
#  '滴滴',
#  '司机',
#  '奇怪',
#  '鸡蛋',
#  '灌饼',
#  '天龙',
#  '农家乐',
#  '拉拉',
#  '歌词',
#  '陈翔',
#  '女朋友',
#  '牢解场',
#  '生活',
#  '微微一笑',
#  '倾城',
#  '豪门',
#  '少奶奶',
#  '谢少',
#  '心尖',
#  '宠妻']

# %%
labels = train.loc[:, ['Age', 'Gender', 'Education']].values
labels
# Out:
# array([[1, 1, 4],
#        [2, 1, 3],
#        [4, 1, 0],
#        ...,
#        [2, 2, 5],
#        [3, 2, 3],
#        [1, 2, 5]])

# %%
label_list = labels.tolist()

# %%
label_list[:5]
# Out:
# [[1, 1, 4], [2, 1, 3], [4, 1, 0], [4, 2, 3], [2, 2, 4]]

# %%
sentences = []
sentences.append((','.join(segs), label_list[0]))
sentences
# Out:
# [('柔和,双沟,女生,中财网,首页,财经,周公,解梦,大全,查询,2345,曹云金,再讽,郭德纲,总裁,大人,行行好,中财网,第一,财经,传媒,教师节,全文,男子,砸毁,15,墓碑,黄岩岛,最新,海图,缘来,迟落,甜心,不好惹,梁朝伟,替身,同框,笑傲江湖,电视剧,任贤齐,小起,名字,女孩,名字,海运,行李,堪培拉,诱爱,99,司少,天价,宝贝,遥控,魔棒,徽信,表情,动态,搞笑,图片,教师节,征文,100,安微,联通,网上,营业厅,甜宠,百分百,校草,萌萌,未婚妻,豪门,重生,之暖爱,成婚,nikehypershift,kd5,好看,韭菜,炒鸡蛋,陈赫,王者,荣耀,虎牙,楚河,三国演义,小说,txt,下载,威县,欧派,好吃,黄岩岛,最新消息,2016,中秋节,诗句,大全,祝福,教师节,征文,菜谱,柔和,双沟,七位数,开奖,以色列,停车场,坍塌,天龙,家庭,农场,7.22,星座,新旧,圣经,合本,下载,wifi,万能钥匙,威灵仙,图片,临泉,长官,天龙,家庭,农场,早安,总统,大人,百合,莲藕,做法,花街,无锡,蚬壳,胃散,触手,忆寒,中秋节,诗句,孟州,电信,电子,发票,鸡丝,做法,临泉,长官,镇桥口,李小刚,农场,朋仇,全民,葱花,蒜苔,炒肉,冰川,图片,kd5,若风,好奇,纸尿裤,清蒸鱼,189.8,平方,重庆,餐馆,发生爆炸,手机,失主,抢劫,家常,做法,三国演义,小说,百度,总裁,掠爱,小舅,太坏,周公,解梦,坦克,冰川,凉拌,藕片,做法,投票,鸡丝,好吃,时光,掩埋,秘密,小说,下载,中国电信,电子,发票,张续,月亮,诗句,酵母,馒头,方法,赵丽颖,碧瑶,触手,兵长,图集,下载,腾讯,新闻,街头,混战,武警,厦门航空,蚬壳,胃散,茄子,做法,身份,类别,方特,生活,强迫症,表现,白袍,法师,图片,朋仇,广场,小宇,热游,馒头,方法,狡滑,黄石,大冶,东岳,派出所,服务,电话,三国演义,小说,下载,txt,松柏,道馆,10.1,高速,免费,几天,三国演义,小说,txt,柔和,双沟,业务,待遇,酵母,馒头,方法,初中,家教,一对一,辅导,口子,中秋节,祝福,诗句,侠岚,王国,42,价格表,1001
#   [1, 1, 4])]

# %% [markdown]
# 整个数据的格式:
# - [用户1， 用户2， 用户3，...]
#
# - 年龄：[('vocab1, vocab2, vocab3, ...', 'age_label')]
# - 性别：[('vocab1, vocab2, vocab3, ...', 'sex_label')]
# - 学历：[('vocab1, vocab2, vocab3, ...', 'education_label')]

# %% [markdown]
# ## 整合数据处理部分

# %% [markdown]
# ### 训练集

# %%
# 停用词
stopwords = pd.read_csv('./total_stop_words.txt', sep='\t', encoding='utf-8', 
                        quoting=3, names=['stopwords'], index_col=False)

stopwords_list = stopwords.stopwords.values
stopwords_list
# Out:
# array(['为止', '纵然', 'all', ..., '欤', '最近', '当前'], dtype=object)

# %%
def query_list_process(x):
    """处理query部分网址等"""
    x = x.replace('\t', ' ').split()
    query_list = []
    for item in x:
        if 'http' not in item and 'ｃｏｍ' not in item and \
            'com' not in item and 'cn' not in item:
            query_list.append(item)
        
    query = ' '.join(query_list)
    return query

# %%
def preprocess_text(sentences, col_names, path):
    train = pd.read_csv(path+'/train.csv', sep="###__###", names=train_col_names,
                        encoding='utf-8', index_col=False)
    query = train.Query_List.apply(query_list_process)
    labels_list = train.loc[:, ['Age', 'Gender', 'Education']].values.tolist()

    out_file = open(path+'out_file.txt', mode='w', encoding='utf-8')
    
    print('分词start....')
    for i in range(query.shape[0]):
        segs = jieba.lcut(query[i], cut_all=False, HMM=True)
        segs = list(filter(lambda x: len(x)>1 and x!='\r\n', segs))
        segs = list(filter(lambda x: x not in stopwords_list, segs))
        sentences.append((','.join(segs), labels_list[i]))
        out_file.write(' '.join(segs) + '\n')
    out_file.close()
    print('处理结束...')

# %%
train_col_names = ['ID', 'Age', 'Gender', 'Education', 'Query_List']
# test_col_names = ['ID', 'Query_list']
path = './data'
sentences = []
preprocess_text(sentences, train_col_names, path)
# Out:
# 分词start....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-4457404d0efa> in <module>
#       3 path = './data'
#       4 sentences = []
# ----> 5 preprocess_text(sentences, train_col_names, path)
#
# <ipython-input-26-17d20c2691cd> in preprocess_text(sentences, col_names, path)
#       9     print('分词start....')
#      10     for i in range(query.shape[0]):
# ---> 11         segs = jieba.lcut(query[i], cut_all=False, HMM=True)
#      12         segs = list(filter(lambda x: len(x)>1 and x!='\r\n', segs))
#      13         segs = list(filter(lambda x: x not in stopwords_list, segs))
#
# ~/anaconda3/lib/python3.7/site-packages/jieba/__init__.py in lcut(self, *args, **kwargs)
#     355
#     356     def lcut(self, *args, **kwargs):
# --> 357         return list(self.cut(*args, **kwargs))
#     358
#     359     def lcut_for_search(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/jieba/__init__.py in cut(self, sentence, cut_all, HMM, use_paddle)
#     323                 continue
#     324             if re_han.match(blk):
# --> 325                 for word in cut_block(blk):
#     326                     yield word
#     327             else:
#
# KeyboardInterrupt:

# %%
query.shape[0]
query[0]
labels_list[0]
